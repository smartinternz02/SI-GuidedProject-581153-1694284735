# %% [markdown]
# # **ASSIGNMENT_0:3_15_Sep - *DATA PRE PROCESSING* Titanic_Dataset**

# %% [markdown]
# # Import The Libraries

# %%
# Importing the necessary libraries which are to be used for data pre-processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy import stats

# %% [markdown]
# # Import The Dataset

# %%
df=pd.read_csv('Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.PassengerId.value_counts()
# Out:
# 1      1
# 599    1
# 588    1
# 589    1
# 590    1
#       ..
# 301    1
# 302    1
# 303    1
# 304    1
# 891    1
# Name: PassengerId, Length: 891, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Ticket.value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-210-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Handling Null Values

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a=(df['Age'].isnull().sum()/df.shape[0])*100
print("Percentage of missing Age record  %.2f%%"%a)
# Out:
# Percentage of missing Age record  19.87%

# %%
sns.histplot(df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
a=(df['Cabin'].isnull().sum()/df.shape[0])*100
print("Percentage of missing Cabin record  %.2f%%"%a)
# Out:
# Percentage of missing Cabin record  77.10%

# %%
a=(df['Embarked'].isnull().sum()/df.shape[0])*100
print("Percentage of missing Embarked record  %.2f%%"%a)
# Out:
# Percentage of missing Embarked record  0.22%

# %%
#IMPUTING missing age value with median
df['Age'].fillna(df['Age'].median(skipna=True),inplace=True)

# %%
sns.distplot(df["Age"])
# Out:
# <ipython-input-219-cf0334540b62>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#imputing Embarked value with mode
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# dtype: bool

# %%
missing_values=df.isnull().sum()
missing_values[missing_values>0]/len(df)*100
# Out:
# Cabin    77.104377
# dtype: float64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.boxplot(df.Age)
plt.show()
# outliers present

# %%
sns.boxplot(df.PassengerId)
plt.show()
# no outlier

# %%
sns.boxplot(df.Survived)
plt.show()
# binary value

# %%
sns.boxplot(df.Pclass)
plt.show()

# %% [markdown]
# ####**Outlier Present**

# %%
sns.boxplot(df.Age)
plt.show()
# outliers present

# %%
sns.boxplot(df.SibSp)
plt.show()
# here outlier show number of sibling present .No need To deal with these outlier as correlation with Survived is negative

# %%
sns.boxplot(df.Parch)
plt.show()

# %%
sns.distplot(df["Parch"])
plt.show()
# Out:
# <ipython-input-233-6ceb901f84f3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Parch"])

# %%
sns.boxplot(df.Fare)
plt.show()
# here outlier imform different the price difference might be because of different passenger class

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Outlier Detection

# %%
#outlier detection for Age only
out=[]
def Zscore_outlier(df):
    m = np.mean(df)
    sd = np.std(df)
    for i in df:
        z = (i-m)/sd
        if np.abs(z) > 3:
            out.append(i)
    print("Outliers:",out)
Zscore_outlier(df['Age'])
# Out:
# Outliers: [71.0, 70.5, 71.0, 80.0, 70.0, 70.0, 74.0]

# %%
#deleting outlier in Age as they are small in number
sns.boxplot(df['Age'])
plt.title("Box Plot Aefore Removing Outlier")
plt.show()

#removing outlier
iqr = 1.5 * (np.percentile(df['Age'], 75) - np.percentile(df['Age'], 25))
df.drop(df[df['Age'] > (iqr + np.percentile(df['Age'], 75))].index, inplace=True)
df.drop(df[df['Age'] < (np.percentile(df['Age'], 25) - iqr)].index, inplace=True)

#showing boxplot after removing age outlier
sns.boxplot(df['Age'])
plt.title("Box Plot After Removing Outlier")
plt.show()

# %%
out=[]
def Zscore_outlier(df):
    m = np.mean(df)
    sd = np.std(df)
    for i in df:
        z = (i-m)/sd
        if np.abs(z) > 3:
            out.append(i)
    print("Outliers:",out)
Zscore_outlier(df['Age'])
#No outlier
# Out:
# Outliers: []

# %% [markdown]
# # Spliting Dependent and Independet Variable

# %%
df.corr().Survived.sort_values(ascending=False)
# as we can see no two attribute have similar correlation to each other
# Out:
# <ipython-input-240-44b74a9debca>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().Survived.sort_values(ascending=False)
# Survived       1.000000
# Fare           0.269672
# Parch          0.074199
# PassengerId   -0.018151
# Age           -0.020926
# SibSp         -0.030860
# Pclass        -0.367774
# Name: Survived, dtype: float64

# %%
X=df.drop(columns='Survived',axis=1)
X = df.drop('Survived', axis=1)  # Independent variables
y = df['Survived']  # Dependent variable

# %%
X.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
y=df['Survived']

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
X.shape
# Out:
# (825, 11)

# %%
y.shape
# Out:
# (825,)

# %%
# Print the shapes of X and y
sns.histplot(data=df, x='Survived', kde=True)
plt.show()

# %% [markdown]
# # Perform Encoding

# %% [markdown]
# ###**Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 825 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  825 non-null    int64
#  1   Pclass       825 non-null    int64
#  2   Name         825 non-null    object
#  3   Sex          825 non-null    object
#  4   Age          825 non-null    float64
#  5   SibSp        825 non-null    int64
#  6   Parch        825 non-null    int64
#  7   Ticket       825 non-null    object
#  8   Fare         825 non-null    float64
#  9   Cabin        176 non-null    object
#  10  Embarked     825 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 109.6+ KB

# %%
le=LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
X['Name']=le.fit_transform(X['Name'])
X
# Out:
#      PassengerId  Pclass  Name     Sex   Age  SibSp  Parch            Ticket  \
# 0              1       3    98    male  22.0      1      0         A/5 21171
# 1              2       1   175  female  38.0      1      0          PC 17599
# 2              3       3   329  female  26.0      0      0  STON/O2. 3101282
# 3              4       1   253  female  35.0      1      0            113803
# 4              5       3    15    male  35.0      0      0            373450
# ..           ...     ...   ...     ...   ...    ...    ...               ...
# 886          887       2   512    male  27.0      0      0            211536
# 887          888       1   282  female  19.0      0      0            112053
# 888          889       3   386  female  28.0      1      2        W./C. 6607
# 889          890       1    72    male  26.0      0      0            111369
# 890          891       3   204    male  32.0      0      0            370376
#
#         Fare Cabin Embarked
# ...

# %%
mapping_Name=dict(zip(le.classes_,range(len(le.classes_))))
mapping_Name
# Out:
# {'Abbing, Mr. Anthony': 0,
#  'Abbott, Mr. Rossmore Edward': 1,
#  'Abbott, Mrs. Stanton (Rosa Hunt)': 2,
#  'Abelson, Mr. Samuel': 3,
#  'Abelson, Mrs. Samuel (Hannah Wizosky)': 4,
#  'Adahl, Mr. Mauritz Nils Martin': 5,
#  'Adams, Mr. John': 6,
#  'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)': 7,
#  'Aks, Mrs. Sam (Leah Rosen)': 8,
#  'Albimona, Mr. Nassef Cassem': 9,
#  'Alexander, Mr. William': 10,
#  'Alhomaki, Mr. Ilmari Rudolf': 11,
#  'Ali, Mr. Ahmed': 12,
#  'Ali, Mr. William': 13,
#  'Allen, Miss. Elisabeth Walton': 14,
#  'Allen, Mr. William Henry': 15,
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)': 16,
#  'Allum, Mr. Owen George': 17,
#  'Andersen-Jensen, Miss. Carla Christine Nielsine': 18,
#  'Anderson, Mr. Harry': 19,
#  'Andersson, Master. Sigvard Harald Elias': 20,
#  'Andersson, Miss. Ebba Iris Alfrida': 21,
#  'Andersson, Miss. Erna Alexandra': 22,
#  'Andersson, Miss. Ingeborg Constanzia': 23,
#  'Andersson, Miss. Sigrid Elisabeth': 24,
# ...

# %%
X['Sex']=le.fit_transform(X['Sex'])
X
# Out:
#      PassengerId  Pclass  Name  Sex   Age  SibSp  Parch            Ticket  \
# 0              1       3    98    1  22.0      1      0         A/5 21171
# 1              2       1   175    0  38.0      1      0          PC 17599
# 2              3       3   329    0  26.0      0      0  STON/O2. 3101282
# 3              4       1   253    0  35.0      1      0            113803
# 4              5       3    15    1  35.0      0      0            373450
# ..           ...     ...   ...  ...   ...    ...    ...               ...
# 886          887       2   512    1  27.0      0      0            211536
# 887          888       1   282    0  19.0      0      0            112053
# 888          889       3   386    0  28.0      1      2        W./C. 6607
# 889          890       1    72    1  26.0      0      0            111369
# 890          891       3   204    1  32.0      0      0            370376
#
#         Fare Cabin Embarked
# 0     7.2500   NaN        S
# ...

# %%
mapping_Sex=dict(zip(le.classes_,range(len(le.classes_))))
mapping_Sex
# Out:
# {'female': 0, 'male': 1}

# %%
X['Ticket']=le.fit_transform(X['Ticket'])
X
# Out:
#      PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0              1       3    98    1  22.0      1      0     494   7.2500
# 1              2       1   175    0  38.0      1      0     565  71.2833
# 2              3       3   329    0  26.0      0      0     635   7.9250
# 3              4       1   253    0  35.0      1      0      41  53.1000
# 4              5       3    15    1  35.0      0      0     446   8.0500
# ..           ...     ...   ...  ...   ...    ...    ...     ...      ...
# 886          887       2   512    1  27.0      0      0      87  13.0000
# 887          888       1   282    0  19.0      0      0      12  30.0000
# 888          889       3   386    0  28.0      1      2     641  23.4500
# 889          890       1    72    1  26.0      0      0       6  30.0000
# 890          891       3   204    1  32.0      0      0     440   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# 1     C85        C
# 2     NaN        S
# ...

# %%
mapping_Ticket=dict(zip(le.classes_,range(len(le.classes_))))
mapping_Ticket
# Out:
# {'110152': 0,
#  '110413': 1,
#  '110465': 2,
#  '110564': 3,
#  '111320': 4,
#  '111361': 5,
#  '111369': 6,
#  '111426': 7,
#  '111427': 8,
#  '111428': 9,
#  '112050': 10,
#  '112052': 11,
#  '112053': 12,
#  '112058': 13,
#  '112059': 14,
#  '112277': 15,
#  '112379': 16,
#  '113028': 17,
#  '113043': 18,
#  '113050': 19,
#  '113051': 20,
#  '113055': 21,
#  '113056': 22,
#  '113059': 23,
#  '113501': 24,
#  '113503': 25,
#  '113505': 26,
#  '113510': 27,
#  '113572': 28,
#  '113760': 29,
#  '113767': 30,
#  '113773': 31,
#  '113776': 32,
#  '113781': 33,
#  '113784': 34,
#  '113786': 35,
#  '113788': 36,
#  '113789': 37,
#  '113794': 38,
#  '113796': 39,
#  '113798': 40,
#  '113803': 41,
#  '113804': 42,
#  '113806': 43,
#  '11668': 44,
#  '11751': 45,
#  '11752': 46,
#  '11753': 47,
#  '11755': 48,
#  '11765': 49,
#  '11767': 50,
#  '11769': 51,
#  '11774': 52,
#  '11813': 53,
#  '11967': 54,
#  '12233': 55,
#  '12460': 56,
#  '12749': 57,
#  '13049': 58,
#  '13214': 59,
# ...

# %%
X['Cabin']=le.fit_transform(X['Cabin'])
X
# Out:
#      PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0              1       3    98    1  22.0      1      0     494   7.2500
# 1              2       1   175    0  38.0      1      0     565  71.2833
# 2              3       3   329    0  26.0      0      0     635   7.9250
# 3              4       1   253    0  35.0      1      0      41  53.1000
# 4              5       3    15    1  35.0      0      0     446   8.0500
# ..           ...     ...   ...  ...   ...    ...    ...     ...      ...
# 886          887       2   512    1  27.0      0      0      87  13.0000
# 887          888       1   282    0  19.0      0      0      12  30.0000
# 888          889       3   386    0  28.0      1      2     641  23.4500
# 889          890       1    72    1  26.0      0      0       6  30.0000
# 890          891       3   204    1  32.0      0      0     440   7.7500
#
#      Cabin Embarked
# 0      128        S
# 1       69        C
# 2      128        S
# ...

# %%
mapping_Cabin=dict(zip(le.classes_,range(len(le.classes_))))
mapping_Cabin
# Out:
# {'A10': 0,
#  'A14': 1,
#  'A16': 2,
#  'A19': 3,
#  'A20': 4,
#  'A24': 5,
#  'A31': 6,
#  'A32': 7,
#  'A34': 8,
#  'A36': 9,
#  'A6': 10,
#  'B101': 11,
#  'B102': 12,
#  'B18': 13,
#  'B20': 14,
#  'B22': 15,
#  'B28': 16,
#  'B3': 17,
#  'B35': 18,
#  'B38': 19,
#  'B39': 20,
#  'B4': 21,
#  'B42': 22,
#  'B49': 23,
#  'B5': 24,
#  'B50': 25,
#  'B51 B53 B55': 26,
#  'B57 B59 B63 B66': 27,
#  'B58 B60': 28,
#  'B69': 29,
#  'B71': 30,
#  'B73': 31,
#  'B77': 32,
#  'B78': 33,
#  'B79': 34,
#  'B82 B84': 35,
#  'B86': 36,
#  'B94': 37,
#  'B96 B98': 38,
#  'C101': 39,
#  'C104': 40,
#  'C106': 41,
#  'C110': 42,
#  'C111': 43,
#  'C118': 44,
#  'C123': 45,
#  'C124': 46,
#  'C125': 47,
#  'C126': 48,
#  'C128': 49,
#  'C148': 50,
#  'C2': 51,
#  'C22 C26': 52,
#  'C23 C25 C27': 53,
#  'C32': 54,
#  'C45': 55,
#  'C46': 56,
#  'C47': 57,
#  'C49': 58,
#  'C52': 59,
#  'C54': 60,
#  'C62 C64': 61,
#  'C65': 62,
#  'C68': 63,
#  'C7': 64,
#  'C70': 65,
#  'C78': 66,
#  'C82': 67,
# ...

# %%
X['Embarked']=le.fit_transform(X['Embarked'])
X
# Out:
#      PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0              1       3    98    1  22.0      1      0     494   7.2500
# 1              2       1   175    0  38.0      1      0     565  71.2833
# 2              3       3   329    0  26.0      0      0     635   7.9250
# 3              4       1   253    0  35.0      1      0      41  53.1000
# 4              5       3    15    1  35.0      0      0     446   8.0500
# ..           ...     ...   ...  ...   ...    ...    ...     ...      ...
# 886          887       2   512    1  27.0      0      0      87  13.0000
# 887          888       1   282    0  19.0      0      0      12  30.0000
# 888          889       3   386    0  28.0      1      2     641  23.4500
# 889          890       1    72    1  26.0      0      0       6  30.0000
# 890          891       3   204    1  32.0      0      0     440   7.7500
#
#      Cabin  Embarked
# 0      128         2
# 1       69         0
# 2      128         2
# ...

# %%
mapping_Embarked=dict(zip(le.classes_,range(len(le.classes_))))

# %%
mapping_Embarked
# Out:
# {'C': 0, 'Q': 1, 'S': 2}

# %%
# Encoding example
# Example: Encode categorical variables like 'Sex' and 'Embarked'
X = pd.get_dummies(X, columns=['Sex', 'Embarked'], drop_first=True)
# df=pd.get_dummies
print(X)
plt.show()
# Out:
#      PassengerId  Pclass  Name   Age  SibSp  Parch  Ticket     Fare  Cabin  \
# 0              1       3    98  22.0      1      0     494   7.2500    128
# 1              2       1   175  38.0      1      0     565  71.2833     69
# 2              3       3   329  26.0      0      0     635   7.9250    128
# 3              4       1   253  35.0      1      0      41  53.1000     45
# 4              5       3    15  35.0      0      0     446   8.0500    128
# ..           ...     ...   ...   ...    ...    ...     ...      ...    ...
# 886          887       2   512  27.0      0      0      87  13.0000    128
# 887          888       1   282  19.0      0      0      12  30.0000     22
# 888          889       3   386  28.0      1      2     641  23.4500    128
# 889          890       1    72  26.0      0      0       6  30.0000     50
# 890          891       3   204  32.0      0      0     440   7.7500    128
#
#      Sex_1  Embarked_1  Embarked_2
# ...

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc
# Out:
# StandardScaler()

# %%
X_scaled=sc.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.73729994,  0.79915529, -1.31845904, ...,  0.7440916 ,
#         -0.31156776,  0.61237244],
#        [-1.73340787, -1.62921714, -0.99514265, ..., -1.34392055,
#         -0.31156776, -1.63299316],
#        [-1.72951581,  0.79915529, -0.34850987, ..., -1.34392055,
#         -0.31156776,  0.61237244],
#        ...,
#        [ 1.71885391,  0.79915529, -0.10917177, ..., -1.34392055,
#         -0.31156776,  0.61237244],
#        [ 1.72274597, -1.62921714, -1.42763081, ...,  0.7440916 ,
#         -0.31156776, -1.63299316],
#        [ 1.72663804,  0.79915529, -0.87337414, ...,  0.7440916 ,
#          3.20957472, -1.63299316]])

# %% [markdown]
# # Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (660, 12) (165, 12) (660,) (165,)
