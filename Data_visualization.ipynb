# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-581153-1694284735/blob/main/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Seaborn car_carshes dataset**
#
# ---

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
sns.scatterplot(x='speeding',y='alcohol',data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %% [markdown]
# #Inference: from the plot we can say that as alcohol is directly propotional to speeding as speed increases after alcohol is consumed

# %%
Inference: from the plot we can say that as alcohol is directly propotional to speeding as speed increases after alcohol is consumed

# %%
sns.scatterplot(x='speeding' , y='not_distracted',data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='not_distracted'>

# %% [markdown]
# #Inference: from the plot we can say that as speeding will be is in limit when driver is not_distracted

# %%
Inference: from the plot we can say that as speeding will be is in limit when driver is not_distracted

# %%
sns.lineplot(x='alcohol',y='speeding', data=df,ci=None)
# Out:
# <ipython-input-16-5ddd56cf448d>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='alcohol',y='speeding', data=df,ci=None)
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %% [markdown]
# #Inference: with inc in alcohol rate speeding also increasing

# %%
Inference: with inc in alcohol rate speeding also increasing

# %%
sns.distplot(df['alcohol'])
# Out:
# <ipython-input-17-570de8ff0310>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['alcohol'])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# #Inference: alcohol rate is mostly ranging between 2 to 5

# %%
Inference: alcohol rate is mostly ranging between 2 to 5

# %%
sns.scatterplot(x='speeding' , y='alcohol',data=df,hue='not_distracted')
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %% [markdown]
# #Inference: when drivers alcohol and speed are more he was more distracted else less distracted

# %%
Inference: when drivers alcohol and speed are more he was more distracted else less distracted

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
car=fig.add_axes([0.1,0.1,0.8,0.8])
sns.barplot(data=df,x='alcohol',y='speeding',ci=None)
# Out:
# <ipython-input-21-e94115d06981>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x='alcohol',y='speeding',ci=None)
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %% [markdown]
# #Inference: when speed is more alcohol density is more

# %%
Inference: when speed is more alcohol density is more

# %%
sns.jointplot(x='not_distracted' , y='speeding',data=df)

# %% [markdown]
# #Inference: speed is more when person got distracted most

# %%
Inference: speed is more when person got distracted most

# %%
sns.boxplot(x='total' , y='not_distracted',data=df)
# Out:
# <Axes: xlabel='total', ylabel='not_distracted'>

# %% [markdown]
# #Inference: it measures how well data is disturbuted between total data and not distracted
# #ql 25% of data
# #q2 50% of data
# #q3 75% of data

# %%
Inference: it measures how well data is
disturbuted between total data and not distracted
ql 25% of data
q2 50% of data
q3 75% of data

# %% [markdown]
# #correlation

# %%
corr=df.corr()
# Out:
# <ipython-input-26-0014364bc22a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
corr
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %% [markdown]
# #Inference: speeding, alcohol, not_distracted are higly correlated as their signifiance is>0.5

# %%
Inference: speeding, alcohol, not_distracted are higly correlated as their signifiance is>0.5

# %%
sns.heatmap(corr,annot=True,cmap='YlOrBr')
# Out:
# <Axes: >

# %% [markdown]
# #Inference: Litter shade of same color represents high correlation than darker ones

# %%
Inference: Litter shade of same color represents high correlation than darker ones

# %%
sns.kdeplot(data=df,shade=True)
# Out:
# <ipython-input-42-4226a2ac3caa>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df,shade=True)
# <Axes: ylabel='Density'>

# %%
car_crashes = sns.load_dataset("car_crashes")
variable_of_interest = 'total'

# %%
sns.kdeplot(data=car_crashes[variable_of_interest], shade=True)
# Out:
# <ipython-input-37-9661c49be8d6>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=car_crashes[variable_of_interest], shade=True)
# <Axes: xlabel='total', ylabel='Density'>

# %% [markdown]
# #Inference:The generated KDE plot provides insights into the distribution of the 'total' variable, which represents the total number of car crashes in different US states

# %%
Inference:The generated KDE plot provides insights into the distribution of the 'total' variable, which represents the total number of car crashes in different US states
